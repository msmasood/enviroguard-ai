# %% [markdown]
# # EnviroGuard AI — Demo Notebook
# Run the monitoring demo and inspect detections.

# %%
from enviroguard.monitor import detect_hazards
print(detect_hazards('data/sample_image.tif'))
